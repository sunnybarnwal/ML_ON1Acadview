# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sunnybarnwal/ML_ON1Acadview/blob/master/House_price_prediction.ipynb)

# %% [markdown]
# #House Price pridiction
# In this assignment our main aim is to train the data set and pridect the price price of house in king country , Seattle (USA).
#
# We are given  with the previous selling price of house between may 2014 to may 2015

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.size
# Out:
# 453873

# %%
df.describe(include='all')
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ##Univariate Analysis
# We will analyse the single variable here

# %%
df['bedrooms'].value_counts().plot(kind='bar')
plt.xlabel("No_of_Bedrooms")
plt.ylabel("Count")
plt.title("No_of_Bedroom vs coult")
plt.show()

# %%
df['bathrooms'].value_counts().plot(kind='bar')
plt.xlabel("No_of_Bathrooms")
plt.ylabel("Count")
plt.title("No_of_Bathroom vs count")
plt.show()

# %%
df['floors'].value_counts().plot(kind='bar')
plt.xlabel("floors")
plt.ylabel("Count")
plt.title("floor vs count")
plt.show()

# %%
df.corr()  #it will show the correlation between the two variables
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
plt.figure(figsize=(30,15))
sns.heatmap(df.corr(),annot=True)
sns.despine()
plt.title("Correlation between columns")
plt.show()

# %%
plt.scatter(df.bedrooms,df.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df.bathrooms,df.price)
plt.title("Bathroom and Price ")
plt.xlabel("Bathrooms")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df.sqft_living,df.price)
plt.title("Square_ft_living and Price ")
plt.xlabel("Square_ft_living")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df.long,df.price)
plt.title("location and Price ")
plt.xlabel("location")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df.waterfront,df.price)
plt.title("waterfront and Price ")
plt.xlabel("waterfront")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(df.lat,df.price)
plt.title("Latitude and Price ")
plt.xlabel("Latitude")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ##Linear Regression
# We have to setup a linear relationship between the data and train the data
#
# We have to split our data into trainning and training set and train our algorithm to predict the price

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
train = df.drop(['id', 'date', 'price'], axis=1)
labels= df['price']

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# We are spliting the data here

# %%
x_train,x_test,y_train,y_test=train_test_split(train,labels,test_size=0.30,random_state=2)

# %% [markdown]
# We train our data here

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lr.intercept_)
# Out:
# 6985043.45289685

# %%
lr.score(x_test,y_test)
# Out:
# 0.706904679413187
